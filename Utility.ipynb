# %%
''' Task 1 : Tuples Create a tuple of five city names, unpack it into five separate variables, and print each variable. 
Then try to modify the first element and handle the resulting error with a try-except block that prints a clear message.
'''
City_names = ('Hyderabad','Bangalore','Mumbai','Chennai','Delhi')
City1, City2, City3, City4, City5 = City_names
print(f'first City: {City1}\nSecond City: {City2}\nThird City: {City3}\nFourth City: {City4}\nFifth City: {City5}')

try:
    City_names[0] = 'Punjab'
except TypeError:
    print("Cannot modify a tuple because it is immutable.")
# Out:
# first City: Hyderabad
# Second City: Bangalore
# Third City: Mumbai
# Fourth City: Chennai
# Fifth City: Delhi
# Cannot modify a tuple because it is immutable.

# %%
'''Task 2 : Sets Create two sets — one for students who passed a Python test and one for students who passed a SQL test. 
Print the union, intersection, and difference (Python-only passers) using set operators.
'''
Python_Passed = {'John','Mary','Daniel','Smith','Kevin'}
SQL_Passed = {'David','John','Smith','Philip','Jane'}

union_set = Python_Passed | SQL_Passed
print(f'union_set : {union_set}')

intersection_set = Python_Passed & SQL_Passed
print(f'intersection_set : {intersection_set}')

difference_set = Python_Passed - SQL_Passed
print(f'difference_set : {difference_set}')
# Out:
# union_set : {'John', 'Philip', 'Jane', 'Mary', 'Smith', 'David', 'Daniel', 'Kevin'}
# intersection_set : {'Smith', 'John'}
# difference_set : {'Mary', 'Daniel', 'Kevin'}

# %%
'''Task 3 — Lists and ASCII Create a list of five integers representing ASCII values. 
Use a loop with chr() to print each integer alongside its corresponding character. 
Then use ord() to retrieve and print the ASCII value of the character 'Z'.
'''
ascii_list = [66,75,80,85,89]
for i in ascii_list:
    print(f'{i}->{chr(i)}')

print(f'ASCII of Z : {ord('Z')}')
# Out:
# 66->B
# 75->K
# 80->P
# 85->U
# 89->Y
# ASCII of Z : 90

# %%
'''Task 4 — Subprocess Use the subprocess module to run the shell command whoami and print the captured output using result.stdout.
'''
import subprocess
result = subprocess.run('whoami', shell=True, capture_output=True, text=True)
print(result.stdout)
# Out:
# pavan2102
